# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
train=pd.read_excel("Data_Train.xlsx")

# %%
test=pd.read_excel("Data_Test.xlsx")

# %%
train.shape
# Out:
# (6237, 9)

# %%
test.shape
# Out:
# (1560, 8)

# %%
df=pd.concat([train,test],axis=0)
# Out:
# C:\Users\ganesh duke\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#             Author                          BookCategory  \
# 0   Chris Kuzneski                    Action & Adventure
# 1     Arun Khopkar  Biographies, Diaries & True Accounts
# 2    Thomas Hobbes                                Humour
# 3  Agatha Christie             Crime, Thriller & Mystery
# 4  Editors of Life              Arts, Film & Photography
#
#                    Edition                         Genre   Price  \
# 0  Paperback,– 10 Mar 2016    Action & Adventure (Books)  220.00
# 1   Paperback,– 7 Nov 2012    Cinema & Broadcast (Books)  202.93
# 2  Paperback,– 25 Feb 1982       International Relations  299.00
# 3   Paperback,– 5 Oct 2017  Contemporary Fiction (Books)  180.00
# 4  Hardcover,– 10 Oct 2006         Photography Textbooks  965.62
#
#                Ratings             Reviews  \
# 0   8 customer reviews  4.0 out of 5 stars
# 1  14 customer reviews  3.9 out of 5 stars
# 2   6 customer reviews  4.8 out of 5 stars
# 3  13 customer reviews  4.1 out of 5 stars
# ...

# %%
df.corr()
# Out:
#        Price
# Price    1.0

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['Author', 'BookCategory', 'Edition', 'Genre', 'Price', 'Ratings',
#        'Reviews', 'Synopsis', 'Title'],
#       dtype='object')

# %%
df["Ratings"].shape
# Out:
# (7789,)

# %%
df.shape
# Out:
# (7789, 9)

# %%
st=df["Ratings"]
string=st.to_string()

# %%
string
# Out:
# '0           8 customer reviews\n1          14 customer reviews\n2           6 customer reviews\n3          13 customer reviews\n4            1 customer review\n5           8 customer reviews\n6          72 customer reviews\n7          16 customer reviews\n8         111 customer reviews\n9            1 customer review\n10        132 customer reviews\n11         17 customer reviews\n12          4 customer reviews\n13          3 customer reviews\n14          5 customer reviews\n15          2 customer reviews\n16           1 customer review\n17         23 customer reviews\n18         76 customer reviews\n19          5 customer reviews\n20         10 customer reviews\n21          2 customer reviews\n22          2 customer reviews\n23         10 customer reviews\n24          9 customer reviews\n25           1 customer review\n26         15 customer reviews\n27         34 customer reviews\n28         17 customer reviews\n29          9 customer reviews\n30         32 customer reviews\n31   
# ...

# %%
type(string)
# Out:
# str

# %%
l=[]
for i in string.split():
    if i.isdigit():
#         print(i)
        l.append(i)
len(l)
# Out:
# 15553

# %%
dff_pd=pd.DataFrame({"Ratingss":l})

# %%
i
# Out:
# 'reviews'

# %%
dff_ser=pd.Series(l)

# %%
dff_pd.shape
# Out:
# (15553, 1)

# %%
dff_ser.shape
# Out:
# (15553,)

# %%
df['Ratings'].nunique()
# Out:
# 368

# %%
df["Ratings"].values
# Out:
# array(['8 customer reviews', '14 customer reviews', '6 customer reviews',
#        ..., '5 customer reviews', '3 customer reviews',
#        '2 customer reviews'], dtype=object)

# %%
df["Ratings"].nunique()
# Out:
# 368

# %%
import re

# %%
Ratings_pr=[]
for j in df["Ratings"]:
    ans=re.findall(r'\d+',j)
    Ratings_pr.append(ans)
    print(ans)
# Out:
# ['8']
# ['14']
# ['6']
# ['13']
# ['1']
# ['8']
# ['72']
# ['16']
# ['111']
# ['1']
# ['132']
# ['17']
# ['4']
# ['3']
# ['5']
# ['2']
# ['1']
# ['23']
# ['76']
# ['5']
# ['10']
# ['2']
# ['2']
# ['10']
# ['9']
# ['1']
# ['15']
# ['34']
# ['17']
# ['9']
# ['32']
# ['2']
# ['49']
# ['49']
# ['10']
# ['8']
# ['62']
# ['61']
# ['1']
# ['8']
# ['7']
# ['5']
# ['18']
# ['16']
# ['6']
# ['3']
# ['2']
# ['98']
# ['12']
# ['14']
# ['3']
# ['97']
# ['1']
# ['7']
# ['2']
# ['2']
# ['7']
# ['5']
# ['285']
# ['29']
# ['1']
# ['27']
# ['4']
# ['267']
# ['24']
# ['7']
# ['6']
# ['2']
# ['146']
# ['1']
# ['4']
# ['1']
# ['95']
# ['1']
# ['234']
# ['35']
# ['3']
# ['5']
# ['7']
# ['2']
# ['4']
# ['66']
# ['1']
# ['15']
# ['8']
# ['20']
# ['39']
# ['9']
# ['6']
# ['3']
# ['7']
# ['7']
# ['12']
# ['171']
# ['13']
# ['2']
# ['2']
# ['9']
# ['2']
# ['7']
# ['399']
# ['1']
# ['7']
# ['42']
# ['2']
# ['2']
# ['2']
# ['142']
# ['4']
# ['10']
# ['62']
# ['3']
# ['1']
# ['1']
# ['15']
# ['5']
# ['6']
# ...

# %%
df["Ratings_prc"]=Ratings_pr

# %%
df.head()
# Out:
#             Author                          BookCategory  \
# 0   Chris Kuzneski                    Action & Adventure
# 1     Arun Khopkar  Biographies, Diaries & True Accounts
# 2    Thomas Hobbes                                Humour
# 3  Agatha Christie             Crime, Thriller & Mystery
# 4  Editors of Life              Arts, Film & Photography
#
#                    Edition                         Genre   Price  \
# 0  Paperback,– 10 Mar 2016    Action & Adventure (Books)  220.00
# 1   Paperback,– 7 Nov 2012    Cinema & Broadcast (Books)  202.93
# 2  Paperback,– 25 Feb 1982       International Relations  299.00
# 3   Paperback,– 5 Oct 2017  Contemporary Fiction (Books)  180.00
# 4  Hardcover,– 10 Oct 2006         Photography Textbooks  965.62
#
#                Ratings             Reviews  \
# 0   8 customer reviews  4.0 out of 5 stars
# 1  14 customer reviews  3.9 out of 5 stars
# 2   6 customer reviews  4.8 out of 5 stars
# 3  13 customer reviews  4.1 out of 5 stars
# ...

# %%
revi=[]
for rev in df["Reviews"]:
    op=re.findall(r"\d.\d+",rev)
    revi.append(op)
revi=str(revi)
revi=int(revi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-50f6215ee278> in <module>
#       4     revi.append(op)
#       5 revi=str(revi)
# ----> 6 revi=int(revi)
#
# ValueError: invalid literal for int() with base 10: "[['4.0'], ['3.9'], ['4.8'], ['4.1'], ['5.0'], ['4.5'], ['4.4'], ['4.7'], ['4.2'], ['4.0'], ['4.9'], ['3.5'], ['4.1'], ['5.0'], ['3.8'], ['5.0'], ['5.0'], ['4.9'], ['4.5'], ['4.3'], ['4.9'], ['5.0'],

# %%
df["Reviews_pr"]=revi

# %%
df.head(10)
# Out:
#                           Author                          BookCategory  \
# 0                 Chris Kuzneski                    Action & Adventure
# 1                   Arun Khopkar  Biographies, Diaries & True Accounts
# 2                  Thomas Hobbes                                Humour
# 3                Agatha Christie             Crime, Thriller & Mystery
# 4                Editors of Life              Arts, Film & Photography
# 5                   Danny Dreyer                                Sports
# 6                Agatha Christie             Crime, Thriller & Mystery
# 7  Sivananda Yoga Vedanta Centre                                Sports
# 8                    M S Ashokan  Biographies, Diaries & True Accounts
# 9                  Maurice Druon                    Action & Adventure
#
#                           Edition                                  Genre  \
# 0         Paperback,– 10 Mar 2016             Action & Adventure (Books)
# ...

# %%
df["Title"].nunique()
# Out:
# 6787

# %%
 df["Reviews"]=df["Reviews"].transform(lambda a:a.rstrip(" out of 5 stars"))

# %%
df["Ratings"]=df["Ratings"].transform(lambda x:x.rstrip(" customer review"))

# %%
df.drop(columns={"Ratings_prc","Reviews_pr"},inplace=True)

# %%
df["Reviews"]=df.Reviews.astype("float")

# %%
df.corr()
# Out:
#             Price   Reviews
# Price    1.000000  0.108158
# Reviews  0.108158  1.000000

# %%
df["Ratings"]=df.Ratings.astype("str")

# %%
df.Ratings
# Out:
# 0         8
# 1        14
# 2         6
# 3        13
# 4         1
# 5         8
# 6        72
# 7        16
# 8       111
# 9         1
# 10      132
# 11       17
# 12        4
# 13        3
# 14        5
# 15        2
# 16        1
# 17       23
# 18       76
# 19        5
# 20       10
# 21        2
# 22        2
# 23       10
# 24        9
# 25        1
# 26       15
# 27       34
# 28       17
# 29        9
#        ...
# 1530      1
# 1531      4
# 1532      1
# 1533     36
# 1534      3
# 1535      6
# 1536      3
# 1537      2
# 1538      2
# 1539      1
# 1540      2
# 1541      1
# 1542     16
# 1543     27
# 1544      2
# 1545      6
# 1546    172
# 1547      7
# 1548      1
# 1549      5
# 1550    296
# 1551     13
# 1552      1
# 1553      1
# 1554      6
# 1555      4
# 1556     13
# 1557      5
# 1558      3
# 1559      2
# Name: Ratings, Length: 7789, dtype: object

# %%
df["Ratings"]=df["Ratings"].transform(lambda x: x.strip())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7789 entries, 0 to 1559
# Data columns (total 9 columns):
# Author          7789 non-null object
# BookCategory    7789 non-null object
# Edition         7789 non-null object
# Genre           7789 non-null object
# Price           6237 non-null float64
# Ratings         7789 non-null object
# Reviews         7789 non-null float64
# Synopsis        7789 non-null object
# Title           7789 non-null object
# dtypes: float64(2), object(7)
# memory usage: 608.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab=LabelEncoder()

# %%
df["Genre"]=lab.fit_transform(df["Genre"])

# %%
df.head()
# Out:
#             Author                          BookCategory  \
# 0   Chris Kuzneski                    Action & Adventure
# 1     Arun Khopkar  Biographies, Diaries & True Accounts
# 2    Thomas Hobbes                                Humour
# 3  Agatha Christie             Crime, Thriller & Mystery
# 4  Editors of Life              Arts, Film & Photography
#
#                    Edition  Genre   Price Ratings  Reviews  \
# 0  Paperback,– 10 Mar 2016      1  220.00       8      4.0
# 1   Paperback,– 7 Nov 2012     78  202.93      14      3.9
# 2  Paperback,– 25 Feb 1982    202  299.00       6      4.8
# 3   Paperback,– 5 Oct 2017     96  180.00      13      4.1
# 4  Hardcover,– 10 Oct 2006    264  965.62       1      5.0
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# ...

# %%
cat_col=pd.get_dummies(df["BookCategory"])

# %%
pd.concat([df,cat_col],axis="columns")
# Out:
#                                                  Author  \
# 0                                        Chris Kuzneski
# 1                                          Arun Khopkar
# 2                                         Thomas Hobbes
# 3                                       Agatha Christie
# 4                                       Editors of Life
# 5                                          Danny Dreyer
# 6                                       Agatha Christie
# 7                         Sivananda Yoga Vedanta Centre
# 8                                           M S Ashokan
# 9                                         Maurice Druon
# 10                                       Rajiv Malhotra
# 11                          Don Tapscott, Alex Tapscott
# 12                                        James Clavell
# 13                                        Wong Kiew Kit
# 14                                     Michael Ondaatje
# 15                                    Matthew K Manning
# ...

# %%
df.Author.nunique()
# Out:
# 4372

# %%
df.describe(include="all").head(2)
# Out:
#        Author BookCategory Edition   Genre   Price Ratings  Reviews Synopsis  \
# count    7789         7789    7789  7789.0  6237.0    7789   7789.0     7789
# unique   4372           11    3882     NaN     NaN     368      NaN     6771
#
#        Title
# count   7789
# unique  6787

# %%
df["Edition"]
# Out:
# 0                    Paperback,– 10 Mar 2016
# 1                     Paperback,– 7 Nov 2012
# 2                    Paperback,– 25 Feb 1982
# 3                     Paperback,– 5 Oct 2017
# 4                    Hardcover,– 10 Oct 2006
# 5                     Paperback,– 5 May 2009
# 6                     Paperback,– 5 Oct 2017
# 7             Hardcover,– Import, 1 Mar 2018
# 8                    Paperback,– 15 Dec 2015
# 9                    Paperback,– 26 Mar 2013
# 10                   Paperback,– 20 Jan 2017
# 11           Paperback,– Import, 14 Jun 2018
# 12                    Paperback,– 1 Jul 1999
# 13                   Paperback,– 15 Nov 2002
# 14                    Paperback,– 1 Sep 2011
# 15                   Paperback,– 26 Feb 2015
# 16                    Hardcover,– 8 Mar 2018
# 17                    Paperback,– 1 Nov 2016
# 18        Mass Market Paperback,– 1 Jan 1991
# 19                          Paperback,– 2016
# 20                   Hardcover,– 24 Nov 2018
# ...

# %%
ed_des=[i.split(",")[0] for i in df["Edition"]]

# %%
df["Edition_des"]=ed_des

# %%
df["Edition_des"].nunique()
# Out:
# 20

# %%
df["Ratings"]=df["Ratings"].transform(lambda x:x.replace(",",""))

# %%
df["Ratings"]=df["Ratings"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7789 entries, 0 to 1559
# Data columns (total 10 columns):
# Author          7789 non-null object
# BookCategory    7789 non-null object
# Edition         7789 non-null object
# Genre           7789 non-null int32
# Price           6237 non-null float64
# Ratings         7789 non-null int32
# Reviews         7789 non-null float64
# Synopsis        7789 non-null object
# Title           7789 non-null object
# Edition_des     7789 non-null object
# dtypes: float64(2), int32(2), object(6)
# memory usage: 608.5+ KB
